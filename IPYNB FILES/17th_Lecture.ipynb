# %%
# EDA ON GLOBAL STATISTICS DATA OF YOUTUBE

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/youtube.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
df.shape
# Out:
# (995, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df = df.drop(['rank', 'Abbreviation', 'country_rank', 'created_month',
             'created_date', 'Gross tertiary education enrollment (%)', 'Unemployment rate', 'Urban_population'], axis=1)

# %%
df.columns
# Out:
# Index(['Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'channel_type', 'video_views_rank',
#        'channel_type_rank', 'video_views_for_the_last_30_days',
#        'lowest_monthly_earnings', 'highest_monthly_earnings',
#        'lowest_yearly_earnings', 'highest_yearly_earnings',
#        'subscribers_for_last_30_days', 'created_year', 'Population',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Youtuber                              0
# subscribers                           0
# video views                           0
# category                             46
# Title                                 0
# uploads                               0
# Country                             122
# channel_type                         30
# video_views_rank                      1
# channel_type_rank                    33
# video_views_for_the_last_30_days     56
# lowest_monthly_earnings               0
# highest_monthly_earnings              0
# lowest_yearly_earnings                0
# highest_yearly_earnings               0
# subscribers_for_last_30_days        337
# created_year                          5
# Population                          123
# Latitude                            123
# Longitude                           123
# dtype: int64

# %%
cat_colms = df.select_dtypes(include =['object']).columns

# %%
df[cat_colms]= df[cat_colms].fillna("Unknown")

# %%
num_colms = df.select_dtypes(include = ['int64', 'float']).columns

# %%
df[num_colms] = df[num_colms].fillna(df[num_colms].mean())

# %%
df.isnull().sum()
# Out:
# Youtuber                            0
# subscribers                         0
# video views                         0
# category                            0
# Title                               0
# uploads                             0
# Country                             0
# channel_type                        0
# video_views_rank                    0
# channel_type_rank                   0
# video_views_for_the_last_30_days    0
# lowest_monthly_earnings             0
# highest_monthly_earnings            0
# lowest_yearly_earnings              0
# highest_yearly_earnings             0
# subscribers_for_last_30_days        0
# created_year                        0
# Population                          0
# Latitude                            0
# Longitude                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Youtuber                          995 non-null    object
#  1   subscribers                       995 non-null    int64
#  2   video views                       995 non-null    float64
#  3   category                          995 non-null    object
#  4   Title                             995 non-null    object
#  5   uploads                           995 non-null    int64
#  6   Country                           995 non-null    object
#  7   channel_type                      995 non-null    object
#  8   video_views_rank                  995 non-null    float64
#  9   channel_type_rank                 995 non-null    float64
#  10  video_views_for_the_last_30_days  995 non-null    float64
# ...

# %%
df.head()
# Out:
#                      Youtuber  subscribers   video views          category  \
# 0                    T-Series    245000000  2.280000e+11             Music
# 1              YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2                     MrBeast    166000000  2.836884e+10     Entertainment
# 3  Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 4                   SET India    159000000  1.480000e+11             Shows
#
#                         Title  uploads        Country   channel_type  \
# 0                    T-Series    20082          India          Music
# 1               youtubemovies        1  United States          Games
# 2                     MrBeast      741  United States  Entertainment
# 3  Cocomelon - Nursery Rhymes      966  United States      Education
# 4                   SET India   116536          India  Entertainment
#
#    video_views_rank  channel_type_rank  video_views_for_the_last_30_days  \
# ...

# %%
df = df.drop(index=2)

# %%
df.head()
# Out:
#                      Youtuber  subscribers   video views          category  \
# 0                    T-Series    245000000  2.280000e+11             Music
# 1              YouTube Movies    170000000  0.000000e+00  Film & Animation
# 3  Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 4                   SET India    159000000  1.480000e+11             Shows
# 5                       Music    119000000  0.000000e+00           Unknown
#
#                         Title  uploads        Country   channel_type  \
# 0                    T-Series    20082          India          Music
# 1               youtubemovies        1  United States          Games
# 3  Cocomelon - Nursery Rhymes      966  United States      Education
# 4                   SET India   116536          India  Entertainment
# 5                       Music        0        Unknown          Music
#
#    video_views_rank  channel_type_rank  video_views_for_the_last_30_days  \
# ...

# %%
df = df.reset_index(drop= True)

# %%
df.head()
# Out:
#                      Youtuber  subscribers   video views          category  \
# 0                    T-Series    245000000  2.280000e+11             Music
# 1              YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2  Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 3                   SET India    159000000  1.480000e+11             Shows
# 4                       Music    119000000  0.000000e+00           Unknown
#
#                         Title  uploads        Country   channel_type  \
# 0                    T-Series    20082          India          Music
# 1               youtubemovies        1  United States          Games
# 2  Cocomelon - Nursery Rhymes      966  United States      Education
# 3                   SET India   116536          India  Entertainment
# 4                       Music        0        Unknown          Music
#
#    video_views_rank  channel_type_rank  video_views_for_the_last_30_days  \
# ...

# %%
df.columns

for col in df.columns:
  if df[col].dtype == 'float64':
    df[col] = df[col].astype('int64')

# %%
df.info()

# %%
channels_in_year= df['created_year'].value_counts()
channels_in_year
# Out:
# created_year
# 2014    98
# 2006    91
# 2011    82
# 2016    77
# 2013    76
# 2015    73
# 2012    72
# 2017    68
# 2009    52
# 2007    49
# 2010    48
# 2018    46
# 2008    46
# 2019    33
# 2020    30
# 2005    24
# 2021    23
# 2022     5
# 1970     1
# Name: count, dtype: int64

# %%
channels_in_year= pd.DataFrame(channels_in_year)
channels_in_year= channels_in_year.reset_index()
channels_in_year.columns = ['Year', 'Created Channels']
channels_in_year
# Out:
#     Year  Created Channels
# 0   2014                98
# 1   2006                91
# 2   2011                82
# 3   2016                77
# 4   2013                76
# 5   2015                73
# 6   2012                72
# 7   2017                68
# 8   2009                52
# 9   2007                49
# 10  2010                48
# 11  2018                46
# 12  2008                46
# 13  2019                33
# 14  2020                30
# 15  2005                24
# 16  2021                23
# 17  2022                 5
# 18  1970                 1

# %%
channels_in_year= channels_in_year.sort_values(by = 'Year', ascending = True)

channels_in_year= channels_in_year.drop(axis= 0, index=[18])

# channels_in_year= channels_in_year.reset_index(drop= True)

channels_in_year
# Out:
#     Year  Created Channels
# 15  2005                24
# 1   2006                91
# 9   2007                49
# 12  2008                46
# 8   2009                52
# 10  2010                48
# 2   2011                82
# 6   2012                72
# 4   2013                76
# 0   2014                98
# 5   2015                73
# 3   2016                77
# 7   2017                68
# 11  2018                46
# 13  2019                33
# 14  2020                30
# 16  2021                23
# 17  2022                 5

# %%
x= channels_in_year['Year']
y= channels_in_year['Created Channels']

fig = plt.figure(figsize =(10, 4))

plt.bar(x, y, color = '#32A645')

plt.xlabel("Year")
plt.ylabel("Number of Channels")
plt.title("Number of Channels created in each Year",  weight = 'bold')


plt.plot(x,y)
plt.show()

# %%
channel_types = df['channel_type'].value_counts()
channel_types
# Out:
# channel_type
# Entertainment    303
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Unknown           30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
plt.pie(channel_types[:-3], labels= channel_types.index[:-3])

plt.title('Distribution of YouTube channels by Type', weight = 'bold')
plt.show()

# %%
channel_orig = df['Country'].value_counts().head(10)
channel_orig
# Out:
# Country
# United States     312
# India             168
# Unknown           122
# Brazil             62
# United Kingdom     43
# Mexico             33
# Indonesia          28
# Spain              22
# Thailand           18
# South Korea        17
# Name: count, dtype: int64

# %%
plt.pie(channel_orig, labels= channel_orig.index)
plt.title('Distribution of YouTube channels by Country - top 10', weight = 'bold')
plt.show()

# %%
colms= ['Youtuber', 'subscribers']

bar_colms= df.loc[0:9, colms]

bar_colms= bar_colms.sort_values('subscribers', ascending = True)

bar_colms['subscribers (M)'] = (bar_colms['subscribers'] / 1000000).astype(int)

bar_colms
# Out:
#                      Youtuber  subscribers  subscribers (M)
# 9           Zee Music Company     96700000               96
# 8               Vlad and Niki     98900000               98
# 7                 Like Nastya    106000000              106
# 6                   PewDiePie    111000000              111
# 5         ýýý Kids Diana Show    112000000              112
# 4                       Music    119000000              119
# 3                   SET India    159000000              159
# 2  Cocomelon - Nursery Rhymes    162000000              162
# 1              YouTube Movies    170000000              170
# 0                    T-Series    245000000              245

# %%
x= bar_colms['Youtuber']
y= bar_colms['subscribers (M)']

fig = plt.figure(figsize =(10, 6))

plt.barh(x, y)

plt.xlabel("No. of Subscribers in million", weight='bold', fontsize = 12)
plt.ylabel("Youtuber", weight='bold', fontsize = 12)
plt.title("Top 10 Youtube Channels by no. of Subscribers", weight='bold', fontsize = 14)
plt.xticks(rotation = 90)
plt.show()

# %%
colms= ['Youtuber', 'video views']

bar_colms= df.loc[0:9, colms]

bar_colms= bar_colms.sort_values('video views', ascending = True)

bar_colms['video views (bil)'] = (bar_colms['video views'] / 1000000000).astype(int)

bar_colms
# Out:
#                      Youtuber   video views  video views (bil)
# 1              YouTube Movies             0                  0
# 4                       Music             0                  0
# 6                   PewDiePie   29058044447                 29
# 9           Zee Music Company   57856289381                 57
# 8               Vlad and Niki   77180169894                 77
# 7                 Like Nastya   90479060027                 90
# 5         ýýý Kids Diana Show   93247040539                 93
# 3                   SET India  148000000000                148
# 2  Cocomelon - Nursery Rhymes  164000000000                164
# 0                    T-Series  228000000000                228

# %%
x= bar_colms['Youtuber']
y= bar_colms['video views (bil)']

fig = plt.figure(figsize =(10, 6))

plt.barh(x, y)

plt.xlabel("Total Video Views in billion", weight='bold', fontsize = 12)
plt.ylabel("Youtuber", weight='bold', fontsize = 12)
plt.title("Top 10 Youtube Channels by total Video Views", weight='bold', fontsize = 14)
plt.show()

# %%
colms= ['subscribers', 'video views']

scatter_colms= df.loc[0:, colms]

scatter_colms['subscribers (MM)'] = (scatter_colms['subscribers'] / 1000000).astype(int)
scatter_colms['video views (bil)'] = (scatter_colms['video views'] / 1000000000).astype(int)

scatter_colms
# Out:
#      subscribers   video views  subscribers (MM)  video views (bil)
# 0      245000000  228000000000               245                228
# 1      170000000             0               170                  0
# 2      162000000  164000000000               162                164
# 3      159000000  148000000000               159                148
# 4      119000000             0               119                  0
# ..           ...           ...               ...                ...
# 989     12300000    9029609749                12                  9
# 990     12300000    1674409945                12                  1
# 991     12300000    2214684303                12                  2
# 992     12300000     374123483                12                  0
# 993     12300000    2129773714                12                  2
#
# [994 rows x 4 columns]

# %%
x= scatter_colms['subscribers (MM)']
y= scatter_colms['video views (bil)']

plt.scatter(x, y, alpha=0.4)

plt.title('Relationship Between no. of Subscribers & total Video Views', fontsize = 14, weight = 'bold')
plt.xlabel('no. of Subscribers in million', fontsize = 12,  weight = 'bold')
plt.ylabel('total Video Views (bil)', fontsize = 12,  weight = 'bold')

plt.show()

# %%
colms= ['video views', 'highest_yearly_earnings']

scatter_colms= df.loc[0:, colms]

scatter_colms['video views (bill)'] = (scatter_colms['video views'] / 1000000000).astype(int)
scatter_colms['highest_yearly_earnings (MM)'] = (scatter_colms['highest_yearly_earnings'] / 1000000).astype(int)

scatter_colms
# Out:
#       video views  highest_yearly_earnings  video views (bill)  \
# 0    228000000000                108400000                 228
# 1               0                        0                   0
# 2    164000000000                 94800000                 164
# 3    148000000000                 87500000                 148
# 4               0                        0                   0
# ..            ...                      ...                 ...
# 989    9029609749                 26500000                   9
# 990    1674409945                  3100000                   1
# 991    2214684303                     3200                   2
# 992     374123483                   185800                   0
# 993    2129773714                  1200000                   2
#
#      highest_yearly_earnings (MM)
# 0                             108
# 1                               0
# 2                              94
# 3                              87
# ...

# %%
x= scatter_colms['video views (bill)']
y= scatter_colms['highest_yearly_earnings (MM)']

plt.scatter(x, y, alpha=0.4)

plt.title('Relationship Between Total Video Views & Highest Yearly Earning', fontsize = 14, weight = 'bold')
plt.xlabel('Total Video Views (bil)', fontsize = 12,  weight = 'bold')
plt.ylabel('Highest Yearly Earning', fontsize = 12,  weight = 'bold')

plt.show()
